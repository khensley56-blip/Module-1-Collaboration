# %%
60 * 60
# Out:
# 3600

# %%
seconds_per_hour = 60 * 60
print("3.2 - Seconds per hour =", seconds_per_hour)
# Out:
# 3.2 - Seconds per hour = 3600

# %%
seconds_per_day = seconds_per_hour * 24
print("3.4 - Seconds in a day =", seconds_per_day)
# Out:
# 3.4 - Seconds in a day = 86400

# %%
division = seconds_per_day / seconds_per_hour

# %%
seconds_per_hour = 60 * 60
seconds_per_day = seconds_per_hour * 24
division = seconds_per_day / seconds_per_hour
print("3.5 - Days divide by hours =", division)
# Out:
# 3.5 - Days divide by hours = 24.0

# %%
seconds_per_hour = 60 * 60
seconds_per_day = seconds_per_hour * 24
division = seconds_per_day / seconds_per_hour
division_2 = seconds_per_day // seconds_per_hour

print("3.2 - Seconds per hour =", seconds_per_hour)
print("3.4 - Seconds in a day =", seconds_per_day)
print("3.5 - Days divide by hours =", division)
print("3.6 - Using integer // = ", division_2)
# Out:
# 3.2 - Seconds per hour = 3600
# 3.4 - Seconds in a day = 86400
# 3.5 - Days divide by hours = 24.0
# 3.6 - Using integer // =  24
