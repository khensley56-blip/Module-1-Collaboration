# %%
secret = 3

# %%
guess = 4

# %%
if guess < secret:
    print("too low")
elif guess > secret:
    print("too high")
else:
    print("just right")
# Out:
# too high

# %%
small = True
green = False

# %%
small = True
green = False
if small and not green:
    print("cherry")
if small and green:
    print("pea")
if not small and gree:
    print("watermelon")
if not small and not green:
    print("pumpkin")
# Out:
# cherry

# %%
for value in [3, 2, 1, 0]:
    print(value)
# Out:
# 3
# 2
# 1
# 0

# %%
guess_me = 7
number = 1
while True:
    if number < guess_me:
        print("too low")
    elif number == guess_me:
        print("found it!")
        break
    else:
        print("oops")
        break
    number += 1
# Out:
# too low
# too low
# too low
# too low
# too low
# too low
# found it!

# %%
guess_me = 5

for number in range(10):
    if number < guess_me:
        print("too low")
    elif number == guess_me:
        print("found it!")
        break
    else:
        print("oops")
        break
# Out:
# too low
# too low
# too low
# too low
# too low
# found it!
