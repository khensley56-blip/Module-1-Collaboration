# %%
#7.4
things = ["mozzarella", "cinderella", "salmonella"]
print(things)
# Out:
# ['mozzarella', 'cinderella', 'salmonella']

# %%
#7.5
things = ["mozzarella", "cinderella", "salmonella"]
things[1] = things[1].capitalize()
print(things)
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']

# %%
7.5 Capitalize the element in things that refers to a person and then print the list. Did it change the element in the list?
Yes changing the element in things changed the list.

# %%
#7.6
things = ["mozzarella", "cinderella", "salmonella"]
things[0] = things[0].upper()
print(things)
# Out:
# ['MOZZARELLA', 'cinderella', 'salmonella']

# %%
#7.7
things = ["mozzarella", "cinderella", "salmonella"]
del things[2]
print(things)
# Out:
# ['mozzarella', 'cinderella']

# %%
#9.1
def good():
    return["Harry", "Ron", "Herminone"]
print(good())
# Out:
# ['Harry', 'Ron', 'Herminone']

# %%
#9.2
def get_odds():
    for number in range(10):
        if number % 2 == 1:
            yield number
for i, value in enumerate(get_odds(), 1):
    if i == 3:
        print("The thirds value returned is:", value)
        break
# Out:
# The thirds value returned is: 5
